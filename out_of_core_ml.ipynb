# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# stream data >
#
# Chunking or batching using pandas , keras, tensorflow, vaex

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2 features extraction

# %% [markdown]
# 3 model train using one by one chunk or batch with the help incremental learning

# %% [markdown]
# not all machine learning algorithms support incremental learning

# %% [markdown]
# sgd, naive, neural network support

# %% [markdown]
# ![image.png](attachment:image.png)
